# %% [markdown]
# <a href="https://colab.research.google.com/github/buswayne/stock_prediction_LSTM_technical_indicators/blob/master/Stock_Price_Prediction_Technical_Indicators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook for stock price prediction using Technical Indicators

# %% [markdown]
# Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Notebook intended to be run in Google Colab --> use TensorFlow GPU for faster computing.

# %% [markdown]
# If you intend to run the code in your PC, use the tf version that fits your requirements

# %%
# %%capture
! pip install tensorflow-gpu==2.1
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
print(tf.__version__)
print(tf.test.gpu_device_name())

# %% [markdown]
# Install and import ta library, library to compute techincal indicators from a dataset

# %%
# %%capture
! pip install --upgrade ta
import ta

# %% [markdown]
# Mount your drive to access the CSV file directly from path

# %%
# %%capture
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Alternatevely, use the colab function and directly load the csv file

# %%
# from google.colab import files
# csv_file = files.upload()

# %% [markdown]
# ## Prepare Dataset

# %%
csv_file = '/content/drive/My Drive/Finance/CSVs/NVDA.csv'
dataset = pd.read_csv(csv_file, index_col='Date')
dataset.index = pd.to_datetime(dataset.index).strftime('%Y-%m-%d')
dataset = ta.utils.dropna(dataset)
print(dataset.shape)
dataset.tail()
# Out:
# (1259, 6)
#                   Open        High  ...   Adj Close    Volume
# Date                                ...
# 2020-04-08  263.410004  267.950012  ...  266.950012  13561100
# 2020-04-09  272.000000  272.920013  ...  262.950012  13156200
# 2020-04-13  260.549988  270.200012  ...  269.850006   9960200
# 2020-04-14  275.000000  285.320007  ...  283.950012  13273700
# 2020-04-15  277.200012  284.170013  ...  280.839996   9128400
#
# [5 rows x 6 columns]

# %% [markdown]
# Add Techical Indicators to the Dataset

# %%
# %%capture
dataset = ta.add_all_ta_features(dataset, open="Open", high="High", low="Low", close="Close", volume="Volume")

# %% [markdown]
# Display the dataset and check how it looks like.
# Final # of columns should be 78

# %%
print(dataset.shape)
display(dataset.head())
# Out:
# (1259, 79)
#                  Open       High        Low  ...  others_dr  others_dlr  others_cr
# Date                                         ...
# 2015-04-16  22.500000  22.690001  22.330000  ... -83.931016         NaN   0.000000
# 2015-04-17  22.020000  22.420000  22.010000  ...  -1.289458   -1.297843  -1.289458
# 2015-04-20  22.299999  22.440001  22.049999  ...  -0.495500   -0.496732  -1.778568
# 2015-04-21  22.360001  22.360001  21.950001  ...  -0.135813   -0.135905  -1.911965
# 2015-04-22  22.190001  22.340000  21.850000  ...   1.133273    1.126900  -0.800360
#
# [5 rows x 79 columns]

# %% [markdown]
# From all the techical indicators created, select the most relevant. Custom decisions can be made, you are welcome to try different indicators and different combinations.

# %%
data = dataset[['Open',
                'High',
                'Low',
                'Close',
                #'volatility_bbm',#'volatility_bbh','volatility_bbl',
                #'trend_ichimoku_a','trend_ichimoku_b',
                'momentum_rsi',
                'trend_macd_diff',
                #'trend_psar',
                #'momentum_stoch','momentum_stoch_signal',
                #'trend_adx'
                ]]

# %% [markdown]
# Drop rows with NaN values. NaN values are related to computation of Moving Averages that require a minimum number of days in the period. Removing NaN values does not affect the performances since only a minimum part of the head of the dataset is removed.

# %%
data = data.dropna()
data.head()
# Out:
#                  Open       High  ...  momentum_rsi  trend_macd_diff
# Date                              ...
# 2015-06-03  22.000000  22.170000  ...     49.897055         0.140265
# 2015-06-04  21.570000  22.160000  ...     55.237023         0.139022
# 2015-06-05  22.020000  22.360001  ...     57.369881         0.142905
# 2015-06-08  22.190001  22.340000  ...     49.716558         0.106074
# 2015-06-09  21.770000  22.020000  ...     51.227852         0.084982
#
# [5 rows x 6 columns]

# %% [markdown]
# Scale the data with MinMaxScaler

# %% [markdown]
# N.B. Define two different scalers: sc for scaling the dataset, sc_Y to be used later to rescale output

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
sc_Y = MinMaxScaler()
scaled_data = sc.fit_transform(data)
sc_Y.fit(data['Close'].values.reshape(-1,1))
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %% [markdown]
# Re-define created sets as DataFrame

# %%
scaled_data = pd.DataFrame(scaled_data, columns=data.columns, index=data.index)
scaled_data.head()
# Out:
#                 Open      High  ...  momentum_rsi  trend_macd_diff
# Date                            ...
# 2015-06-03  0.009369  0.008895  ...      0.460113         0.593732
# 2015-06-04  0.007904  0.008861  ...      0.539198         0.593643
# 2015-06-05  0.009437  0.009535  ...      0.570786         0.593922
# 2015-06-08  0.010016  0.009468  ...      0.457439         0.591277
# 2015-06-09  0.008585  0.008390  ...      0.479822         0.589763
#
# [5 rows x 6 columns]

# %% [markdown]
# ## Split data_X in Train and Test set

# %% [markdown]
# **Idea of the algorithm:** use the last **N_past** days to predict the **M_future** days.\
# In general, increasing N_past increases the accuracy of the model.
# Viceversa, incresing M_future decreases the accuracy of the model.

# %% [markdown]
# Notice however that a too high value of N_past not only increases the complexity of the model, but also can lead to worse result if the market is in a high volatility period.\
# \
# Also in this case, try different combinations.

# %%
N_past = 7
M_future = 3

# %%
test_percentage = 0.15
test_split = int(len(scaled_data)*(1 - test_percentage))

# %%
train = scaled_data[:test_split]
test = scaled_data[test_split-N_past:]
print(train.shape)
print(test.shape)
# Out:
# (1042, 6)
# (191, 6)

# %% [markdown]
# Create a function to prepare X and y sets to be used in the regression.

# %% [markdown]
# X will be an array with length = len(train). Each element i of the array will have shape (N_past, number_of_regressors), representing the N_past days x the selected technical features for that day.

# %% [markdown]
# Y will be an array with length = len(train). Each element i of the array will have shape (M_future, 1), representing the M_future days Close prices.

# %% [markdown]
# Example: N_past = 10, M_future = 5.
# The 15th element of X will contain (15th,16th,17th,..24th) day, and each day is described by selected features.
# The 15th element of Y will contain (25th,26th,27th) day Closing price.

# %% [markdown]
# The function iterates from day 0 to day (len(data) - past - future)  because we need N_past days to make the prediction and N_future days to assign the Y value.
# Jump is a variable used to skip values in order to avoid superimposition between predicted values. During training and testing it is = 1 because we exploit each (X,y) couple to train/test.

# %%
def split_dataset_X_Y(data, past, future, jump=1):
  X,Y = [],[]
  for i in range(0, len(data) - past - future + 1, jump):
    X.append(data[i : (i+past)].values)
    Y.append(data['Close'][(i + past) : (i + past + future)])
  return np.array(X), np.array(Y)

# %%
X_train, y_train = split_dataset_X_Y(train, N_past, M_future)
X_test, y_test = split_dataset_X_Y(test, N_past, M_future)

# %% [markdown]
# Split train into train and validation sets

# %%
from sklearn.model_selection import train_test_split
X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_validation.shape)
print(y_validation.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (826, 7, 6)
# (826, 3)
# (207, 7, 6)
# (207, 3)
# (182, 7, 6)
# (182, 3)

# %% [markdown]
# ## LSTM Model

# %%
EPOCHS = 100

# %%
model = Sequential()
model.add(LSTM(8, input_shape=(N_past, data.shape[1]), return_sequences=True))
# model.add(Dropout(0.2))
# model.add(LSTM(64, return_sequences=True))
# model.add(Dropout(0.2))
model.add(LSTM(8))
# model.add(Dropout(0.2))
model.add(Dense(M_future))
model.compile(loss='mean_squared_error', optimizer='rmsprop')
model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_28 (LSTM)               (None, 7, 8)              480
# _________________________________________________________________
# lstm_29 (LSTM)               (None, 8)                 544
# _________________________________________________________________
# dense_14 (Dense)             (None, 3)                 27
# =================================================================
# Total params: 1,051
# Trainable params: 1,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=EPOCHS, validation_data=(X_validation, y_validation), shuffle=True, batch_size=8, verbose=2)
# Out:
# Train on 826 samples, validate on 207 samples
# Epoch 1/100
# 826/826 - 4s - loss: 0.0350 - val_loss: 0.0015
# Epoch 2/100
# 826/826 - 1s - loss: 0.0012 - val_loss: 0.0020
# Epoch 3/100
# 826/826 - 1s - loss: 0.0010 - val_loss: 0.0014
# Epoch 4/100
# 826/826 - 1s - loss: 9.8220e-04 - val_loss: 0.0016
# Epoch 5/100
# 826/826 - 1s - loss: 9.8694e-04 - val_loss: 9.0357e-04
# Epoch 6/100
# 826/826 - 1s - loss: 9.0446e-04 - val_loss: 0.0017
# Epoch 7/100
# 826/826 - 1s - loss: 9.0072e-04 - val_loss: 8.7390e-04
# Epoch 8/100
# 826/826 - 1s - loss: 8.5860e-04 - val_loss: 8.7407e-04
# Epoch 9/100
# 826/826 - 1s - loss: 8.5250e-04 - val_loss: 9.9250e-04
# Epoch 10/100
# 826/826 - 1s - loss: 7.9813e-04 - val_loss: 9.6127e-04
# Epoch 11/100
# 826/826 - 1s - loss: 7.6668e-04 - val_loss: 7.6991e-04
# Epoch 12/100
# 826/826 - 1s - loss: 7.9791e-04 - val_loss: 7.5572e-04
# Epoch 13/100
# 826/826 - 1s - loss: 7.8596e-04 - val_loss: 8.3578e-04
# Epoch 14/100
# 826/826 - 1s - loss: 7.5489e-04 - val_loss: 7.2739e-04
# Epoch 15/100
# 826/826 - 1s - loss: 7.4976e-04 - val_loss: 0.0019
# Epoch 16/100
# 826/826 - 1s - loss: 6.7945e-04 - val_loss: 0.0014
# Epoch 17/100
# 826/826 - 1s - loss: 7.0263e-04 - val_loss: 0.0021
# Epoch 18/100
# 826/826 - 1s - loss: 7.2455e-04 - val_loss: 7.7856e-04
# Epoch 19/100
# 826/826 - 1s - loss: 6.8160e-04 - val_loss: 6.9448e-04
# Epoch 20/100
# 826/826 - 1s - loss: 6.9722e-04 - val_loss: 8.2706e-04
# Epoch 21/100
# 826/826 - 1s - loss: 6.5113e-04 - val_loss: 8.4094e-04
# Epoch 22/100
# 826/826 - 1s - loss: 7.0389e-04 - val_loss: 7.9134e-04
# Epoch 23/100
# 826/826 - 1s - loss: 7.0731e-04 - val_loss: 6.7509e-04
# Epoch 24/100
# 826/826 - 1s - loss: 6.7758e-04 - val_loss: 6.9172e-04
# Epoch 25/100
# 826/826 - 1s - loss: 6.7521e-04 - val_loss: 7.4250e-04
# Epoch 26/100
# 826/826 - 1s - loss: 6.5147e-04 - val_loss: 6.5957e-04
# Epoch 27/100
# 826/826 - 1s - loss: 6.4405e-04 - val_loss: 7.6812e-04
# Epoch 28/100
# 826/826 - 1s - loss: 6.7728e-04 - val_loss: 6.5417e-04
# Epoch 29/100
# 826/826 - 1s - loss: 6.3408e-04 - val_loss: 7.2182e-04
# Epoch 30/100
# 826/826 - 1s - loss: 6.2430e-04 - val_loss: 0.0013
# Epoch 31/100
# 826/826 - 1s - loss: 6.0246e-04 - val_loss: 6.7531e-04
# Epoch 32/100
# 826/826 - 1s - loss: 6.2094e-04 - val_loss: 9.1485e-04
# Epoch 33/100
# 826/826 - 1s - loss: 6.6646e-04 - val_loss: 8.1864e-04
# Epoch 34/100
# 826/826 - 1s - loss: 6.2932e-04 - val_loss: 9.7664e-04
# Epoch 35/100
# 826/826 - 1s - loss: 5.9333e-04 - val_loss: 6.2998e-04
# Epoch 36/100
# 826/826 - 1s - loss: 6.5303e-04 - val_loss: 0.0023
# Epoch 37/100
# 826/826 - 1s - loss: 6.0127e-04 - val_loss: 9.1486e-04
# Epoch 38/100
# 826/826 - 1s - loss: 6.0872e-04 - val_loss: 9.8932e-04
# Epoch 39/100
# 826/826 - 1s - loss: 5.9175e-04 - val_loss: 7.5413e-04
# Epoch 40/100
# 826/826 - 1s - loss: 5.8345e-04 - val_loss: 0.0024
# Epoch 41/100
# 826/826 - 1s - loss: 5.8115e-04 - val_loss: 0.0014
# Epoch 42/100
# 826/826 - 1s - loss: 5.9406e-04 - val_loss: 0.0012
# Epoch 43/100
# 826/826 - 1s - loss: 5.8006e-04 - val_loss: 7.2466e-04
# Epoch 44/100
# 826/826 - 1s - loss: 6.0161e-04 - val_loss: 7.7823e-04
# Epoch 45/100
# 826/826 - 1s - loss: 5.9790e-04 - val_loss: 6.0727e-04
# Epoch 46/100
# 826/826 - 1s - loss: 5.7357e-04 - val_loss: 6.6502e-04
# Epoch 47/100
# 826/826 - 1s - loss: 5.7745e-04 - val_loss: 0.0012
# Epoch 48/100
# 826/826 - 1s - loss: 5.5286e-04 - val_loss: 7.5374e-04
# Epoch 49/100
# 826/826 - 1s - loss: 5.5517e-04 - val_loss: 6.8079e-04
# Epoch 50/100
# 826/826 - 1s - loss: 5.5260e-04 - val_loss: 0.0010
# Epoch 51/100
# 826/826 - 1s - loss: 5.6313e-04 - val_loss: 6.5969e-04
# Epoch 52/100
# 826/826 - 1s - loss: 5.2135e-04 - val_loss: 6.1253e-04
# Epoch 53/100
# 826/826 - 1s - loss: 5.3265e-04 - val_loss: 9.5233e-04
# Epoch 54/100
# 826/826 - 1s - loss: 5.7632e-04 - val_loss: 5.8624e-04
# Epoch 55/100
# 826/826 - 1s - loss: 5.4078e-04 - val_loss: 7.4087e-04
# Epoch 56/100
# 826/826 - 1s - loss: 5.4367e-04 - val_loss: 0.0014
# Epoch 57/100
# 826/826 - 1s - loss: 5.5527e-04 - val_loss: 7.6556e-04
# Epoch 58/100
# 826/826 - 1s - loss: 5.3875e-04 - val_loss: 5.4462e-04
# Epoch 59/100
# 826/826 - 1s - loss: 5.3095e-04 - val_loss: 9.5325e-04
# Epoch 60/100
# 826/826 - 1s - loss: 5.4849e-04 - val_loss: 5.3768e-04
# Epoch 61/100
# 826/826 - 1s - loss: 5.0899e-04 - val_loss: 7.5214e-04
# Epoch 62/100
# 826/826 - 1s - loss: 5.4825e-04 - val_loss: 6.8439e-04
# Epoch 63/100
# 826/826 - 1s - loss: 5.3037e-04 - val_loss: 5.4719e-04
# Epoch 64/100
# 826/826 - 1s - loss: 5.3005e-04 - val_loss: 6.1051e-04
# Epoch 65/100
# 826/826 - 1s - loss: 5.3501e-04 - val_loss: 5.3306e-04
# Epoch 66/100
# 826/826 - 1s - loss: 5.1782e-04 - val_loss: 5.4620e-04
# Epoch 67/100
# 826/826 - 1s - loss: 5.2261e-04 - val_loss: 5.6652e-04
# Epoch 68/100
# 826/826 - 1s - loss: 5.1162e-04 - val_loss: 5.6433e-04
# Epoch 69/100
# 826/826 - 1s - loss: 5.1580e-04 - val_loss: 0.0011
# Epoch 70/100
# 826/826 - 1s - loss: 5.1799e-04 - val_loss: 5.4997e-04
# Epoch 71/100
# 826/826 - 1s - loss: 5.2341e-04 - val_loss: 7.6428e-04
# Epoch 72/100
# 826/826 - 1s - loss: 4.8821e-04 - val_loss: 5.7336e-04
# Epoch 73/100
# 826/826 - 1s - loss: 5.0284e-04 - val_loss: 5.5442e-04
# Epoch 74/100
# 826/826 - 1s - loss: 5.2006e-04 - val_loss: 5.3260e-04
# Epoch 75/100
# 826/826 - 1s - loss: 4.8580e-04 - val_loss: 5.5593e-04
# Epoch 76/100
# 826/826 - 1s - loss: 5.1489e-04 - val_loss: 0.0014
# Epoch 77/100
# 826/826 - 1s - loss: 5.0504e-04 - val_loss: 8.0930e-04
# Epoch 78/100
# 826/826 - 1s - loss: 4.8599e-04 - val_loss: 5.9966e-04
# Epoch 79/100
# 826/826 - 1s - loss: 4.9748e-04 - val_loss: 6.4986e-04
# Epoch 80/100
# 826/826 - 1s - loss: 5.0268e-04 - val_loss: 8.4761e-04
# Epoch 81/100
# 826/826 - 1s - loss: 5.1894e-04 - val_loss: 7.1550e-04
# Epoch 82/100
# 826/826 - 1s - loss: 4.8596e-04 - val_loss: 5.8871e-04
# Epoch 83/100
# 826/826 - 1s - loss: 4.8718e-04 - val_loss: 9.3972e-04
# Epoch 84/100
# 826/826 - 1s - loss: 5.0100e-04 - val_loss: 9.3462e-04
# Epoch 85/100
# 826/826 - 1s - loss: 4.9267e-04 - val_loss: 5.6495e-04
# Epoch 86/100
# 826/826 - 1s - loss: 4.6784e-04 - val_loss: 0.0013
# Epoch 87/100
# 826/826 - 1s - loss: 4.6168e-04 - val_loss: 9.9494e-04
# Epoch 88/100
# 826/826 - 1s - loss: 4.8207e-04 - val_loss: 5.9095e-04
# Epoch 89/100
# 826/826 - 1s - loss: 4.8698e-04 - val_loss: 0.0011
# Epoch 90/100
# 826/826 - 1s - loss: 4.7695e-04 - val_loss: 5.9734e-04
# Epoch 91/100
# 826/826 - 1s - loss: 4.9007e-04 - val_loss: 9.1444e-04
# Epoch 92/100
# 826/826 - 1s - loss: 4.6246e-04 - val_loss: 0.0010
# Epoch 93/100
# 826/826 - 1s - loss: 4.7697e-04 - val_loss: 0.0011
# Epoch 94/100
# 826/826 - 1s - loss: 4.7530e-04 - val_loss: 5.6811e-04
# Epoch 95/100
# 826/826 - 1s - loss: 4.9180e-04 - val_loss: 5.0829e-04
# Epoch 96/100
# 826/826 - 1s - loss: 4.7278e-04 - val_loss: 5.4330e-04
# Epoch 97/100
# 826/826 - 1s - loss: 4.5775e-04 - val_loss: 5.6847e-04
# Epoch 98/100
# 826/826 - 1s - loss: 4.6568e-04 - val_loss: 5.9425e-04
# Epoch 99/100
# 826/826 - 1s - loss: 4.9121e-04 - val_loss: 6.4718e-04
# Epoch 100/100
# 826/826 - 1s - loss: 4.7771e-04 - val_loss: 6.8563e-04

# %% [markdown]
# ### Plot Loss vs Validation Loss

# %%
plt.figure(figsize = (7,4), dpi=150)
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## Predict over the test set

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# Create a DataFrame with y_test and y_pred. Since element of y_test[i,1] is equal to element of y_test[i+1,0], let's take only y_test[:,0], which are the Close prices of the **first day** of the predictions i.

# %%
df = pd.DataFrame({'y_test': sc_Y.inverse_transform(y_test[:,0].reshape(-1,1)).flatten(),
                   'y_pred': sc_Y.inverse_transform(y_pred[:,0].reshape(-1,1)).flatten()},
                   test[N_past:N_past+len(y_test)].index)

# %%
fig = plt.figure(figsize=(10,4), dpi=150)
df['y_test'].plot()
df['y_pred'].plot()
plt.legend(loc='best')
plt.title('Test predictions: 1 day ahead')
plt.grid(True)
plt.show()

# %% [markdown]
# Notice that the further in time we try to predict the Close price, the worse the predictions are (it makes sense). Compare the previous plot with the following, where last Close prices in the prediction window are taken into consideration.

# %%
df_2 = pd.DataFrame({'y_test': sc_Y.inverse_transform(y_test[:,-1].reshape(-1,1)).flatten(),
                   'y_pred': sc_Y.inverse_transform(y_pred[:,-1].reshape(-1,1)).flatten()},
                   test[N_past+M_future-1:].index)

# %%
fig = plt.figure(figsize=(10,4), dpi=150)
df_2['y_test'].plot()
df_2['y_pred'].plot()
plt.legend(loc='best')
plt.title('Test predictions: %i days ahead'%M_future)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Prediction of the overall dataset

# %% [markdown]
# Conceptually repeat the step above, this time jumping in time by M_future days each time

# %% [markdown]
# Since the algorithm requires N_past days, the Train-Test split must be adjusted to predict all the Time Series

# %%
train = scaled_data[(test_split-M_future-N_past) % M_future : test_split]
test = scaled_data[test_split - N_past:]
print(train.shape)
print(test.shape)
# Out:
# (1042, 6)
# (191, 6)

# %%
X_train, y_train = split_dataset_X_Y(train, N_past, M_future, M_future)
X_test, y_test = split_dataset_X_Y(test, N_past, M_future, M_future)

# %% [markdown]
# Check that last day in y_train is the day before the first day in y_test.

# %%
print('Last Close price for y_train is %.6f'%(y_train[-1][-1]))
print('First Close price for y_test is %.6f'%(y_test[0][0]))
display(test.iloc[N_past-1:N_past+1])
# Out:
# Last Close price for y_train is 0.529300
# First Close price for y_test is 0.539456
#                 Open      High  ...  momentum_rsi  trend_macd_diff
# Date                            ...
# 2019-07-23  0.523474  0.526332  ...      0.760018         0.655496
# 2019-07-24  0.538805  0.536945  ...      0.798507         0.672039
#
# [2 rows x 6 columns]

# %% [markdown]
# Make predictions over the Train set

# %%
train_predictions = model.predict(X_train).ravel()

# %% [markdown]
# Make predictions over the Test set

# %%
test_predictions = model.predict(X_test).ravel()

# %% [markdown]
# Combine y_train and y_test in an unique vector y_true, target values

# %%
y_true = np.concatenate((y_train.ravel(), y_test.ravel()), axis=0)

# %% [markdown]
# Adjust train_predictions and test_predictions with NaN values so that they have the same length and can be plotted together

# %%
for _ in range(len(y_true)-len(train_predictions)):
  train_predictions = np.append(train_predictions, np.nan)
  
for _ in range(len(y_true)-len(test_predictions)):
  test_predictions = np.insert(test_predictions, 0, np.nan, axis=0)

# %%
assert (y_true.shape == train_predictions.shape == test_predictions.shape)

# %% [markdown]
# Create a Final DataFrame with the true values and the predicted values

# %%
lb = (test_split-M_future-N_past) % M_future + N_past
ub = lb + len(y_true)

# %%
complete_df = pd.DataFrame({'y_true': sc_Y.inverse_transform(y_true.reshape(-1,1)).flatten(),
                            'train_predictions': sc_Y.inverse_transform(train_predictions.reshape(-1,1)).flatten(),
                            'test_predictions': sc_Y.inverse_transform(test_predictions.reshape(-1,1)).flatten()},
                           data[lb:ub].index)

# %% [markdown]
# Static Plot

# %%
fig = plt.figure(figsize=(10,4), dpi=150)
complete_df['y_true'].plot(linewidth=0.6)
complete_df['train_predictions'].plot(linewidth=0.6)
complete_df['test_predictions'].plot(linewidth=0.6)
plt.legend(loc='best')
plt.title('Predict %i days into the future from the last %i past days'%(M_future,N_past))
plt.grid(True)
plt.show()

# %% [markdown]
# Interactive Plot

# %%
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=complete_df.index,
                         y=complete_df['y_true'],
                         name='True',
                         mode='lines',
                         line = dict(color='steelblue',
                                     width=2)))
fig.add_trace(go.Scatter(x=complete_df.index,
                         y=complete_df['train_predictions'],
                         name='Predicted over Train',
                         mode='lines',
                         line = dict(color='darkorange',
                                     width=2)))
fig.add_trace(go.Scatter(x=complete_df.index,
                         y=complete_df['test_predictions'],
                         name='Predicted over Test',
                         mode='lines',
                         line = dict(color='green',
                                     width=2)))
fig.update_layout(
    xaxis=dict(
        showline=True,
        showgrid=True,
        gridcolor='rgb(204, 204, 204)',
        showticklabels=True,
        linecolor='black',
        linewidth=1,
        ticks='outside',
        tickfont=dict(
            family='Arial',
            size=12,
            color='rgb(82, 82, 82)',
        )),
    yaxis=dict(
        showgrid=True,
        gridcolor='rgb(204, 204, 204)',
        linewidth=0.3,
        linecolor='black',
        zeroline=True,
        showline=True,
        showticklabels=True,
    ),
    title={
    'text': 'Predict %i days into the future from the last %i past days'%(M_future,N_past),
    'y':0.9,
    'x':0.5,
    'xanchor': 'center',
    'yanchor': 'top'},
    yaxis_title='Price',
    xaxis_title='Date',
    autosize=False,
    width=1440,
    height=608,
    plot_bgcolor='white')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="52ed74e5-3b78-43ee-abf8-c8c76d9f32dd" class="plotly-graph-div" style="height:608px; width:1440px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("52ed74e5-3b78-43ee-abf8-c8c76d9f32dd")) {
#                     Plotly.newPlot(
#                         '52ed74e5-3b78-43ee-abf8-c8c76d9f32dd',
#                         [{"line": {"color": "steelblue", "width": 2}, "mode": "lines", "name": "True", "type": "scatter", "x": ["2015-06-12", "2015-06-15", "2015-06-16", "2015-06-17", "2015-06-18", "2015-06-19", "2015-06-22", "2015-06-23", "2015-06-24", "2015-06-25", "2015-06-26", "2015-06-29", "2015-06-30", "2015-07-01", "2015-07-02", "2015-07-06", "2015-07-07", "2015-07-08", "2015-07-09", "2015-07-10", "2015-07-13", "2015-07-14", "2015-07-15", "2015-07-16", "2015-07-17", "2015-07-20", "2015-07-21", "2015-07-22", "2015-07-23", "2015-07-24", "2015-07-27", "2015-07-28", "2015-07-29", "2015-07-30", "2015-07-31", "2015-08-03", "2015-08-04", "2015-08-05", "2015-08-06", "2015-08-07", "2015-08-10", "2015-08-11", "2015-08-12", "2015-08-13", "2015-08-14", "2015-08-17", "2015-08-18", "2015-08-19", "2015-08-20", "2015-08-21", "2015-08-24", "2015-08-25", "2015-08-26", "2015-08-27", "2015-08-28", "2015-08-31", "2015-09-01", "2015-09-02", "2015-09-03", "2015-09-04", "2015-09-08", "2015-09-09", "2015-09-10", "2015-09-11", "2015-09-14", "2015-09-15", "2015-09-16", "2015-09-17", "2015-09-18", "2015-09-21", "2015-09-22", "2015-09-23", "2015-09-24", "2015-09-25", "2015-09-28", "2015-09-29", "2015-09-30", "2015-10-01", "2015-10-02", "2015-10-05", "2015-10-06", "2015-10-07", "2015-10-08", "2015-10-09", "2015-10-12", "2015-10-13", "2015-10-14", "2015-10-15", "2015-10-16", "2015-10-19", "2015-10-20", "2015-10-21", "2015-10-22", "2015-10-23", "2015-10-26", "2015-10-27", "2015-10-28", "2015-10-29", "2015-10-30", "2015-11-02", "2015-11-03", "2015-11-04", "2015-11-05", "2015-11-06", "2015-11-09", "2015-11-10", "2015-11-11", "2015-11-12", "2015-11-13", "2015-11-16", "2015-11-17", "2015-11-18", "2015-11-19", "2015-11-20", "2015-11-23", "2015-11-24", "2015-11-25", "2015-11-27", "2015-11-30", "2015-12-01", "2015-12-02", "2015-12-03", "2015-12-04", "2015-12-07", "2015-12-08", "2015-12-09", "2015-12-10", "2015-12-11", "2015-12-14", "2015-12-15", "2015-12-16", "2015-12-17", "2015-12-18", "2015-12-21", "2015-12-22", "2015-12-23", "2015-12-24", "2015-12-28", "2015-12-29", "2015-12-30", "2015-12-31", "2016-01-04", "2016-01-05", "2016-01-06", "2016-01-07", "2016-01-08", "2016-01-11", "2016-01-12", "2016-01-13", "2016-01-14", "2016-01-15", "2016-01-19", "2016-01-20", "2016-01-21", "2016-01-22", "2016-01-25", "2016-01-26", "2016-01-27", "2016-01-28", "2016-01-29", "2016-02-01", "2016-02-02", "2016-02-03", "2016-02-04", "2016-02-05", "2016-02-08", "2016-02-09", "2016-02-10", "2016-02-11", "2016-02-12", "2016-02-16", "2016-02-17", "2016-02-18", "2016-02-19", "2016-02-22", "2016-02-23", "2016-02-24", "2016-02-25", "2016-02-26", "2016-02-29", "2016-03-01", "2016-03-02", "2016-03-03", "2016-03-04", "2016-03-07", "2016-03-08", "2016-03-09", "2016-03-10", "2016-03-11", "2016-03-14", "2016-03-15", "2016-03-16", "2016-03-17", "2016-03-18", "2016-03-21", "2016-03-22", "2016-03-23", "2016-03-24", "2016-03-28", "2016-03-29", "2016-03-30", "2016-03-31", "2016-04-01", "2016-04-04", "2016-04-05", "2016-04-06", "2016-04-07", "2016-04-08", "2016-04-11", "2016-04-12", "2016-04-13", "2016-04-14", "2016-04-15", "2016-04-18", "2016-04-19", "2016-04-20", "2016-04-21", "2016-04-22", "2016-04-25", "2016-04-26", "2016-04-27", "2016-04-28", "2016-04-29", "2016-05-02", "2016-05-03", "2016-05-04", "2016-05-05", "2016-05-06", "2016-05-09", "2016-05-10", "2016-05-11", "2016-05-12", "2016-05-13", "2016-05-16", "2016-05-17", "2016-05-18", "2016-05-19", "2016-05-20", "2016-05-23", "2016-05-24", "2016-05-25", "2016-05-26", "2016-05-27", "2016-05-31", "2016-06-01", "2016-06-02", "2016-06-03", "2016-06-06", "2016-06-07", "2016-06-08", "2016-06-09", "2016-06-10", "2016-06-13", "2016-06-14", "2016-06-15", "2016-06-16", "2016-06-17", "2016-06-20", "2016-06-21", "2016-06-22", "2016-06-23", "2016-06-24", "2016-06-27", "2016-06-28", "2016-06-29", "2016-06-30", "2016-07-01", "2016-07-05", "2016-07-06", "2016-07-07", "2016-07-08", "2016-07-11", "2016-07-12", "2016-07-13", "2016-07-14", "2016-07-15", "2016-07 ...

# %% [markdown]
# ## Predict Future Values!!

# %% [markdown]
# To make an actual prediction, select the very last available N days and reshape them so that the sample can be fed into our model (expected 3D)

# %%
last_days = scaled_data[-N_past:].values.reshape(1, N_past, -1)

# %%
prediction = model.predict(last_days)
prediction = sc_Y.inverse_transform(prediction).flatten()

# %% [markdown]
# Here the predicted prices for the next days!!

# %%
data[-1:]
# Out:
#                   Open        High  ...  momentum_rsi  trend_macd_diff
# Date                                ...
# 2020-04-15  277.200012  284.170013  ...     57.882237         4.219138
#
# [1 rows x 6 columns]

# %%
print('Predicted prices for the future %i days are:'%M_future)
for price in prediction:
  print(price)
# Out:
# Predicted prices for the future 3 days are:
# 269.337
# 269.04053
# 271.06323
